# %% [markdown]
# # Task 157: AI-Based Driver Drowsiness and Distraction Detection
#
# This notebook demonstrates the execution of the Driver Drowsiness and Distraction Detection system. It imports `utils.py`, configures the detection parameters, runs the pipeline on a test video, and plots the results.

# %%
import os
import sys
import cv2
import matplotlib.pyplot as plt
from PIL import Image

# Ensure the code directory is in path
sys.path.append(os.path.abspath('.'))

# %% [markdown]
# ### Run the Drowsiness Detection Pipeline
#
# We can trigger the main python pipeline script directly from here. Ensure you specify the input video path.

# %%
# Define the input video path
video_path = '../../AI_GIRL/Recording 2026-06-26 105823.mp4'  # Update as needed

if os.path.exists(video_path):
    print("Executing drowsiness detection on:", video_path)
    # !python detect.py --video "{video_path}"
else:
    print("Test video not found. Please verify the path.")

# %% [markdown]
# ### Display the Generated Analytics Dashboard
#
# After execution, the system saves a premium dark-themed dashboard plot representing driver distraction events, speed correlation, and drowsiness timeline.

# %%
dashboard_path = '../Outputs/analytics_dashboard.png'
if os.path.exists(dashboard_path):
    img = Image.open(dashboard_path)
    plt.figure(figsize=(12, 8))
    plt.imshow(img)
    plt.axis('off')
    plt.show()
else:
    print("Dashboard plot not found. Run the pipeline first to generate it.")
