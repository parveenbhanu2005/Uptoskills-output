# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00069.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000139.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00090.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000135.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00059.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00034.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00023.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00079.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000113.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00067.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00016.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000138.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00072.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000163.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00074.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00096.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000105.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00073.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00031.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00065.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000118.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000124.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00056.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000153.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00099.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00029.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00064.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00065.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0003.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00057.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000112.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000107.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00036.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000168.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00047.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00087.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0006.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00096.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00037.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0005.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00095.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000138.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000102.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0005.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000154.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00083.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000123.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00045.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00071.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00038.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000108.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000140.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000104.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000115.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00072.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000108.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00060.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00052.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000142.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0004.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000137.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00028.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00039.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00068.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000131.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00076.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000166.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00048.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00074.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000136.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000106.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00073.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00021.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0007.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000148.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00012.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000157.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00084.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000102.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000101.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00066.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000143.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00053.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00047.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00041.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000153.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00062.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000122.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00077.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00036.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00020.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000157.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000145.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00012.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000146.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000112.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00061.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00022.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000119.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00040.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000109.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00049.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00025.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00088.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000117.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00010.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00015.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000109.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00055.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000107.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00044.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0008.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0001.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00024.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000171.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00053.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000142.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00070.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000144.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00093.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00058.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00032.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00078.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00084.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00051.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00016.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0002.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00013.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00075.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00030.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000165.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000122.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00062.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00061.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00076.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00025.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00067.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00046.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00041.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00045.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00023.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00068.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00034.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00051.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00027.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000110.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000134.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00024.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000155.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00086.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000159.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00097.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000172.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00017.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00087.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000110.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0004.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000128.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000132.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000123.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000116.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00086.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000147.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000150.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00057.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00040.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000114.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000121.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000169.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00085.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000111.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000133.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000152.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000116.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000156.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00054.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00090.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00013.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00050.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000155.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000104.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00033.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00094.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00046.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0006.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000101.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00035.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000151.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000163.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000100.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000119.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00028.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000140.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00043.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00088.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00069.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000133.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0002.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00079.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000126.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00019.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00098.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00042.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000127.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00014.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00050.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00091.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00019.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00094.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00026.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000172.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00093.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000121.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000164.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00048.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00020.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00031.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000111.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00080.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000105.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00042.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000114.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000156.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00018.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00027.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00099.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000152.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00081.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000158.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000118.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000161.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00033.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000151.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000168.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000165.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00054.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000124.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00059.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00043.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0009.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000159.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000158.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000125.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00015.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00063.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000162.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000130.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000167.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00077.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000126.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000135.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000160.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00083.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00080.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000125.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00060.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00049.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00091.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000128.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000120.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000103.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000127.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00055.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00010.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000149.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00037.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000131.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00097.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000103.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00056.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00058.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000171.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00044.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00092.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0009.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000100.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00021.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000117.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000143.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000149.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00081.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00095.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00026.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000139.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00082.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000120.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00092.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0001.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00039.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000160.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000129.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00014.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000137.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00018.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00035.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000169.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00071.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00017.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00089.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00064.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000167.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000164.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00082.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000115.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00070.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000113.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00029.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00066.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00063.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00011.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00075.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000129.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000132.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000148.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000170.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000145.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00052.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00022.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00030.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00078.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000150.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000106.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00085.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00032.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000147.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0007.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000161.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000170.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000141.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0003.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000144.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000134.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00098.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000130.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00011.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000141.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000136.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00089.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000154.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000166.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000146.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_00038.xml
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_0008.jpg
# /kaggle/input/datasets/prachiii33/garbageds/Garbage/Garbage_bin_000162.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/README.dataset.txt
# /kaggle/input/datasets/prachiii33/garbagebin/README.roboflow.txt
# /kaggle/input/datasets/prachiii33/garbagebin/data.yaml
# /kaggle/input/datasets/prachiii33/garbagebin/valid/labels/gettyimages-1230349822-612x612_jpg.rf.9d026acbaa0120cd9fdabb71c0cfc30a.txt
# /kaggle/input/datasets/prachiii33/garbagebin/valid/labels/IMG_20211120_095040_jpg.rf.2ce059c7b3a9f889ec0a1d112a9e28b7.txt
# /kaggle/input/datasets/prachiii33/garbagebin/valid/labels/17_jpg.rf.c2f32dfa5d4d51492a47283db6c25273.txt
# /kaggle/input/datasets/prachiii33/garbagebin/valid/labels/-24-11-2021-235712_jpg.rf.d12bfa2a4c4611b46132a0fad31002fe.txt
# /kaggle/input/datasets/prachiii33/garbagebin/valid/labels/IMG_20211120_094555_jpg.rf.ddde4f379077619c75fe456354b86a04.txt
# /kaggle/input/datasets/prachiii33/garbagebin/valid/labels/IMG_20211120_094203_jpg.rf.2e4df3f2a7b0131be165f66005c3bd76.txt
# /kaggle/input/datasets/prachiii33/garbagebin/valid/labels/IMG_20220404_173924_jpg.rf.00c829b68abdbe68b461caed739c81fd.txt
# /kaggle/input/datasets/prachiii33/garbagebin/valid/labels/-24-11-2021-235935_jpg.rf.6d932053de7177f25faf2d6f0f468a34.txt
# /kaggle/input/datasets/prachiii33/garbagebin/valid/labels/-24-11-2021-234815_jpg.rf.2cff2a8668f3a8c1369ac7987a443af1.txt
# /kaggle/input/datasets/prachiii33/garbagebin/valid/labels/-24-11-2021-235100_jpg.rf.eeb8a783f440a3914340dec464a7afcf.txt
# /kaggle/input/datasets/prachiii33/garbagebin/valid/labels/IMG_20211120_100141_jpg.rf.c74fd0fb617e4043758df68c80d317d8.txt
# /kaggle/input/datasets/prachiii33/garbagebin/valid/images/-24-11-2021-235712_jpg.rf.d12bfa2a4c4611b46132a0fad31002fe.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/valid/images/-24-11-2021-235100_jpg.rf.eeb8a783f440a3914340dec464a7afcf.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/valid/images/IMG_20211120_095040_jpg.rf.2ce059c7b3a9f889ec0a1d112a9e28b7.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/valid/images/IMG_20211120_100141_jpg.rf.c74fd0fb617e4043758df68c80d317d8.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/valid/images/-24-11-2021-235935_jpg.rf.6d932053de7177f25faf2d6f0f468a34.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/valid/images/gettyimages-1230349822-612x612_jpg.rf.9d026acbaa0120cd9fdabb71c0cfc30a.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/valid/images/IMG_20211120_094555_jpg.rf.ddde4f379077619c75fe456354b86a04.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/valid/images/IMG_20211120_094203_jpg.rf.2e4df3f2a7b0131be165f66005c3bd76.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/valid/images/IMG_20220404_173924_jpg.rf.00c829b68abdbe68b461caed739c81fd.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/valid/images/-24-11-2021-234815_jpg.rf.2cff2a8668f3a8c1369ac7987a443af1.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/valid/images/17_jpg.rf.c2f32dfa5d4d51492a47283db6c25273.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/test/labels/gettyimages-157396726-612x612-1-_jpg.rf.d511619afb59326a55d17c6ccfcb2d39.txt
# /kaggle/input/datasets/prachiii33/garbagebin/test/labels/48_jpg.rf.eb86677ba9f0114f2131b7c9acbc3169.txt
# /kaggle/input/datasets/prachiii33/garbagebin/test/images/48_jpg.rf.eb86677ba9f0114f2131b7c9acbc3169.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/test/images/gettyimages-157396726-612x612-1-_jpg.rf.d511619afb59326a55d17c6ccfcb2d39.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/72_jpg.rf.0e5837e0e5866046eb0975a1d91f93d4.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/gettyimages-1255472365-612x612_jpg.rf.2950614e5e63c8e29dc6d61f430cf885.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1058_jpg.rf.8fc60cdc8a97db91b9ae9415acf22eed.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-87_jpg.rf.f6a0b6ce04223beb0d4793bcdc896c73.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_174404_jpg.rf.5248440af7cfe93e618e71f16b36d77e.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3250_jpg.rf.56eac70eb5f37698486c54d2ec2a98c7.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_173858_jpg.rf.8400b762c6518cdeb756469d8d987ebb.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1652767312293_jpg.rf.de7ec4a434c39698ccec5330b60680cd.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1910_jpg.rf.b79bd27d7846e29bbbfd92861f31789a.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/TEST2_COTY20HP_jpeg.rf.96f0b4cace1e44748f620c16b49d5642.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/vse-o-ploshchadkah-dlya-musornyh-kontejnerov-5_jpg.rf.911a6598a60c14734708cebf70fe91db.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/571_jpg.rf.8dd75f8c08252181d22cc5c70ba1f9b8.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/images30_jpg.rf.b4e7e19edc3ee55be94725ae4bbc0e29.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-25-11-2021-083140_jpg.rf.1cb919c5c967c0262fcd81542c1fc323.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-79_jpg.rf.f38997fc00dd2e126f4134d32ebeefff.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1103_blur_jpg.rf.cfaa4ecd678f6fe7936e41906792ee4e.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/image3_jpeg.rf.54d3e23dbb52e7b4fc0b81f569c98edd.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20211120_100144_jpg.rf.96df27ce85524b64556e3bf3b659074b.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3988-jpg_gridmask_jpg.rf.fd991644bf9089cc3900755823685d37.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/701_jpg.rf.486a78fe3ec34343fd5a5541de6a5d6a.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_170050_jpg.rf.49a75864393567c5ea6fe1ca05918122.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/419_jpg.rf.13665ae9113835a75072accc30fd2037.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/and-litter-vector-recycle-can-with-pile-of-plastic-waste-street-dump-2D6FYYM_jpg.rf.eaa86411f56e33f94b7dc58321a18b9a.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/landfill-broken-objects-refugee-camp-garbage-dump-trash-162413542_jpg.rf.8a86407a77403ffb72cb46c741645012.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_171813_jpg.rf.6c066c5ad15ed5c3d63c56f583ced5a6.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-24-11-2021-234544_jpg.rf.b667af388190a61c3abf896a51414b31.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/image24_jpeg.rf.66c1857673e80c32f5b7dd445dea1356.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/gettyimages-471550333-612x612_jpg.rf.dfbf0e9b34a83e2cf76eb9c05c3cff1e.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-24-11-2021-235458_jpg.rf.eac0a75cda3c9ee21adc764b982bb10e.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_165332_jpg.rf.835aabfa676bcdffd1816a7459cc76e1.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3433-jpg_blur-jpg_gridmask_jpg.rf.e2793e4ff522130552b4e5cd344bf334.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-25-11-2021-083150_jpg.rf.f393dfa154acdafdc601962faaffe723.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/5443_jpg.rf.399b0502213a5442e85aaa18cff022f8.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/image11_jpeg.rf.5975ddfd77f92fe69ee66d3c82ff6aa0.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_170255_jpg.rf.1716838fe5f419918b6dd69a5b6c6382.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/_117684205_lotus_jpg.rf.9ed4794c6e633fb2b125902563133555.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/833_jpg.rf.5f13562acf0587d8d89d8071b6766acd.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1937-jpg_blur-jpg_gridmask_jpg.rf.a5441b66c28609640eecbbfc3c96a4a2.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/gettyimages-894699700-612x612_jpg.rf.d7ae67f16d73d0bbbfc76ef7d3696732.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/images-2-_jpg.rf.3627d7f2fb6a88ec447bcb5605cf7d0d.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1362_jpg.rf.cfb2096de569cf971ae263c378fb440a.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_165955_jpg.rf.8996d4f26ed19195bb80d3077b250af3.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-30_jpg.rf.7463b9416947db2b6ea6ba21bcf97676.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/images28_jpg.rf.df6267f6b57a529e7e26cc0b05033208.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/870_jpg.rf.3a0f703b889035e158329d1cc722ab69.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/vse-o-ploshchadkah-dlya-musornyh-kontejnerov-7_jpg.rf.897e4706083e95dba574767bec3024f2.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_170333_jpg.rf.2f73888bcf4054cbda0136f13ced3f39.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/Car_jpg.rf.0c2892fb74be171ed77bd3b935dbb250.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/image30_jpeg.rf.4e3790a503272da60ee1064f549c376f.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20211120_093244_jpg.rf.83b4c841db2f4f75e6f4be2d4b078bee.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1477_jpg.rf.5e14864443c3cf5e91c19371cfbb89f0.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/50_jpg.rf.c34f5a5b3961650e22dcd5fbce65e2e9.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_171837_jpg.rf.d8e83bea0c7fa3cb292333a90d6da05e.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/_109791516_gettyimages-155382228_jpg.rf.da7f199d3bc7a5a97ff6fc56f554c7a8.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_201424_jpg.rf.b0c24995a94ce6c77a43657bc9a1aacd.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/5399_jpg.rf.ea5dcbeaaf927c3392e008257348e4c9.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3447-jpg_gridmask_jpg.rf.75ceb3773a44148e298e11a1dc1d0c69.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20211120_095846_jpg.rf.aafba3c2a71d89006d2e7a04d2cb9145.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3824-jpg_blur_jpg.rf.7a88540b208960e382edc5855c430f4a.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-24-11-2021-235140_jpg.rf.7b0d8e8e1d69e7ffd768e960acdcca34.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_165353_jpg.rf.bfe046231bcd95153cf74cf89b17c447.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/516_jpg.rf.2ca5ffdc3c632cd7210b8dc8f00690b6.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1831_jpg.rf.0b89a62bcf624aa55d1b40fd4649bf34.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1652767312605_jpg.rf.50c233721285ab4d77ce66a4511c3617.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3516-jpg_blur-jpg_gridmask_jpg.rf.1aded4f95eff0a4a9b8e165f07f4a74c.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/21_jpg.rf.89fe2207f2b82632d385ec491ecf5d3e.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/35_jpg.rf.7de484163d313c644bf5df2a4c23efe7.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/images15_jpg.rf.067652192072ec627a1741650dc01e17.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/images-6-_jpg.rf.bfcdf96ddcb2efef0eb10740521b7dd2.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1036-jpg_blur_jpg.rf.e5afe01efca48cfc734c42bb2a196cdf.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/785-jpg_gridmask_jpg.rf.f29d28a9047e9b1e8ac26b1b7d6783e1.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-81_jpg.rf.9cb2e985170b26188d86558476e242d0.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_171517_jpg.rf.3beaa2d5a8cb2f33782154ea51ac8402.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/23_jpg.rf.8a884028c4e37b6f125f1b5066514df7.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/mn_jpg.rf.c90e45aab05d755192176f4c00a8b9b2.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1053_jpg.rf.707fdbb5fa7d1857ace2aa4a8ead66eb.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/596_jpg.rf.15d06ebdb25866a5a5a6e03a3ab34f4b.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/images32_jpg.rf.71a784282657ad3a82a3c43e768a5676.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/images-16-_jpg.rf.c815d92f87c8f0c1b4a58a17b98fcbd6.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/image24_jpeg.rf.8e01d3d752368d5a36edd0bb5534fee9.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/720CARS20COTY20202220AWARS_0_jpg.rf.24d38fac5c9aa2a2f702c4ed6c29a1d4.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/67897757_728520064266636_963326469746982912_n-1_jpg.rf.2a38363e08c837a6f0721a6ad3a42ae9.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/bukit-batok-trash-overflows-3_jpg.rf.f2be59d0a7f8986575a69f169388c7e5.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/image17_jpeg.rf.8c02f63060ba5ea68acf3ed15e8e3e07.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/image20_jpeg.rf.d3883152834bee50fc41d172b1900506.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_173911_jpg.rf.364ba0ef4d5029a0d96b675954d50779.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_170042_jpg.rf.7016df9f00f824ee2dec91ee27730988.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/gettyimages-1263836816-612x612_jpg.rf.4dbf43b1afa754544aa6e81bf82a381e.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_172505_jpg.rf.01eda34031d2a97ff42c8451e0492615.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/696_jpg.rf.db2772e17ff9100006c5841ec0681a3d.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3481_jpg.rf.a11ab7e9a2bbc8c475138fd7d60693c7.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/Tips-To-Keep-Your-Car-Looking-Brand-New_jpg.rf.54d5cd793de75b908fcb837a0a91972b.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3236_jpg.rf.e215cc330bce293c751100822d4836f8.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/5263_jpg.rf.ae568a46c8882211733a1661a0ca8d38.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20211120_095936_jpg.rf.67bce857109cd1374792ac844666b7cc.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/car_noun_001_02258_jpg.rf.5a46bfe76d6f191e3d4888108dae6c5b.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/rasstojanie-do-musornyh-kontejnerov-2_jpg.rf.fa2f7b2212b68e2a328ed4a0ec5784da.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3345_jpg.rf.284c12f9b6b7f3555d8348a74fe65bdd.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/images4_jpg.rf.22a5734723d0d61d3da3e2527dfb75a9.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/garbage-24_jpg.rf.45f3055e77abd0742d83add117353163.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/broken-garbage-can-trash-city-park-summer-day-95353021_jpg.rf.156a1640448bc32c58059625060425bd.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/garbage-30_jpg.rf.a6a9cdf08aaf8ce7b8aafa6650019fff.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3843_jpg.rf.94471483ff0f697f34b4b7d026971b89.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/490_jpg.rf.bb344beeb4d40a850e76fe798d141789.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3962_jpg.rf.7fb441d5ec6d7e438820304736c3f2b3.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/images41_jpg.rf.6d8f39ceff515e34bac9819ec587f670.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3015_jpg.rf.efb37f605926c7226f90b57420f73f2f.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/4671_jpg.rf.1f334eef0fe2f66954a8954d7f9156bb.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1934_jpg.rf.c75477750aa5952591c5902d25bbd9d1.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-24-11-2021-235049_jpg.rf.59f7e76d4e7da22fe981a4adf05c53b8.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20211120_095240_jpg.rf.942602ee3cec4eda2efdb0ec59c8f9c1.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/4259_jpg.rf.04dffb887d92be44aaf19ef7e8972d73.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/2059_jpg.rf.864bd404ca08632ff87ea9f3aaec1840.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20211120_095109_jpg.rf.c3639a2cc67fdf8e216c944fda02466a.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/kushaq-exterior-right-front-three-quarter-52_jpeg.rf.47791c78e3525ef6b65bf9c53b384aa5.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_171034_jpg.rf.108bfcaeed8e362f829c51bcbc049ed2.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/2203_jpg.rf.ac39fe9119db46572c5c849a3e4dd9db.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/56_jpg.rf.15138de22e37b479c924953805ca9bf6.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/gettyimages-1138822598-612x612_jpg.rf.db7d3a10ba156c534505e264127638f7.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/ba_jpg.rf.b24e886739c327e061d4dc8f80197203.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-25-11-2021-083734_jpg.rf.e5dc270e25899aa9a72cdb306190d7b5.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20211120_095922_jpg.rf.f89e6f70a30eba36c68f09bc620accfe.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_171028_jpg.rf.17a7d998d7a1ca9cfca5544489e625cb.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/5447_jpg.rf.6742679ca97e94be613657535fa3593c.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_170516_jpg.rf.a7474c8fd119587bd9a13a7dfaca6dc4.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1900_jpg.rf.d810d97df587392a943e0de0c68000f0.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/images-9-_jpg.rf.289af91d5a711db3f8181b082536f4c5.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3978_jpg.rf.d155452b8e37e059bf4c05d84e1ce036.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/2667-jpg_gridmask_jpg.rf.7e3f28a25ab347745f3d6cf01c396c60.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/43_jpg.rf.ddff3614ad0af25b412699feb093ab3f.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_170502_jpg.rf.be978adceb497dc7fc26c3ad815f19b5.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-24-11-2021-234957_jpg.rf.1c5757860fda5090255e22dd160f7c33.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20211120_095542_jpg.rf.f2158ce80582c98f240324608985aec0.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3193-jpg_blur_jpg.rf.139b8475901a485e18d6ff960c35a9a3.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3648-jpg_blur-jpg_gridmask_jpg.rf.c65ef3c8a4cc2a9e6877298549dab8a5.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/3934_jpg.rf.9213611eeee8c6f3bdbcccfa94190aa0.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1570_jpg.rf.ead47a283ce7cb1efdf93140b6f2630f.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/4910_jpg.rf.c1bcbe4dce929bf11e097de5b88e71c2.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_171512_jpg.rf.e44f9aab12a635470e30ada9e9698971.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-25-11-2021-083058_jpg.rf.6854d83fc7318ba6c6970fae8450d851.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/2_jpg.rf.203ab5cbf3cf7dffc75bd43f03d90f72.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/e_jpg.rf.7ac121823449836b65f7c8aebae2307c.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/image17_jpeg.rf.76d28bc0a69b7b7dd08911dc38c994e1.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/4026-jpg_gridmask_jpg.rf.52161f786aac6aa22127d34bd90a23de.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/Broken-Bin-Lids-213117_jpg.rf.29ae6c19bf97ab963522848234218f64.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220404_171055_jpg.rf.d60429709d6a25767caff0ed114ac034.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/images21_jpg.rf.690873f0fc00e2abb6656e1c877c823a.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/images45_jpg.rf.355e26ef2b3aeeb12e3eaeecdcf9d497.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20211120_093157_jpg.rf.6ccc7585fcc22f6fa8d2f8f9f976fdc2.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/4952_jpg.rf.ee543375eb2e212cc106ad14a7a13234.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/file76fikjtx2tgrkkhzbaf-1008973628-1564688975_jpg.rf.54d08f3641d5b8a54b8155831903c7db.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/IMG_20220405_211557_jpg.rf.3c39ce70678c4a708ccccf7b864b456f.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1188_jpg.rf.e2d221db18747ac8210f756f072ba9a1.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1774_blur_jpg.rf.aaa2d8e6c2925e45ca020fbffd8381df.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-89_jpg.rf.210596f19a3ccd3d9d5e0002452801b7.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/1591_jpg.rf.505c26efad54c9cd530c18e1bca4bb0d.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/8c1b5552-6799-11e5-8dc4-40f2e96c8ad8_jpg.rf.0b418e1c5d11dfa4238a57ec8ccb9287.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/stock-vector-do-not-put-broken-glass-in-the-recycle-waste-bin-vector-illustration-1076421176_jpg.rf.ecabf9a328511e525e3e9a9a219ee2e5.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/-24-11-2021-235104_jpg.rf.97acadac84504a0d1968ccedc7a2328a.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/4150-jpg_blur-jpg_gridmask_jpg.rf.e9a225ee84c24d3a0ba0e85e85652d05.txt
# /kaggle/input/datasets/prachiii33/garbagebin/train/labels/overflowing-trash-bin_jpg.rf.35732b5aeead9c011ef12685ea63623e.txt
# ...
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20211120_094545_jpg.rf.9b0fb242f8d1d050cfcc36b8ea1ab19e.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1939_jpg.rf.9e72b082686a519dc85401beb76717a0.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_171804_jpg.rf.f41df609ac12f35fca0473952b096ad2.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1612_jpg.rf.6683e8a19ef7add5ea06d1e05d9244a8.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_165211_jpg.rf.2c152254992b8913c7ff49f6c42ae9c8.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/gettyimages-1283166923-612x612_jpg.rf.e886c816c71f06a294417916cf8a6624.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1775_jpg.rf.4945a81fd3ebdad59195bb8e89f45dcb.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/garbage-28_jpg.rf.7e3bbec1dc7e6ab65ccaf92d587fa1d4.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/3988-jpg_gridmask_jpg.rf.fd991644bf9089cc3900755823685d37.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1831_jpg.rf.0b89a62bcf624aa55d1b40fd4649bf34.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/images35_jpg.rf.724beef2160fb876c01c1c09daa1c199.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/5637_jpg.rf.1798ca8d6cc0db038eb907b9167070b1.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_170855_jpg.rf.7997cb30d72783438e6afc9c7455b0f4.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/images53_jpg.rf.18845914565e7dcc28cb266c2d056aca.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/3971-jpg_gridmask_jpg.rf.8cbcfda8cf86c390783d3d16b1ed9c6e.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1360_jpg.rf.f1615b82d8d397b89730e1a1b91dfd08.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20211120_092913_jpg.rf.990e27a871320616e7be94d50089bad5.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/181_jpg.rf.874fa9b20c49363e699e7d432d751964.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/-24-11-2021-235614_jpg.rf.4248e7e402bd44cd3648d4999d7b057a.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/-49_jpg.rf.fca6034b086e63eccf6bdd1bf7366bcd.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/3351_jpg.rf.f20a82586ce1e3d10b759e44b9f2285a.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/459_jpg.rf.b36a8c8827e60abe9aca42cff975dcf0.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_171055_jpg.rf.d60429709d6a25767caff0ed114ac034.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/3640-jpg_blur_jpg.rf.16b447a155b3cec63d35f0c9ef4c3920.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1899_blur_gridmask_jpg.rf.5139f9a255845d7efc6783c86478f1cd.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1267_jpg.rf.7ccd373680180a05543ce37d620fb346.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20211120_093511_jpg.rf.4d00e78b4452c991603d0215da394ac3.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_170557_jpg.rf.4eb481166512daa2165ff0170eee592a.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/images50_jpg.rf.e8cf6d147253e4096109576471896d9a.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/501_jpg.rf.95fd49b4c7f2d793c248b6efa62b08ae.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/495_jpg.rf.4b58d894b07b9e7bbd0285e1f290aa9a.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/gettyimages-1327496328-612x612_jpg.rf.7039c41fb23bcdfeebd0d78513f78f46.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20211120_092641_jpg.rf.c5cfe6397bb624cfcf4ee336e9f17b78.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20211120_093001_jpg.rf.ee966470bcfb0f7656fd9ee0b4a9131f.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1327-jpg_blur_jpg.rf.55edb8cf427f192709798114a0fcfcdc.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/941_jpg.rf.4ff3ece8f7edd0883b14bc25422183ad.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/3298-jpg_blur_jpg.rf.f5acd4a2fa8883ff22ba27de6842034b.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/4671_jpg.rf.1f334eef0fe2f66954a8954d7f9156bb.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1179_jpg.rf.3a66f797ca475795914a1cfe86ab5204.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220405_211831_jpg.rf.c265e06847e5c3165271aac727a38747.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/3934_jpg.rf.9213611eeee8c6f3bdbcccfa94190aa0.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/broken-screen-mobile-phone-and-green-stock-photograph_csp82089695_jpg.rf.437405e5690c486cdd15190f62122f31.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/62_jpg.rf.7601e0597e591f1041485ad72cc45ed8.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_173521_jpg.rf.85cc11ce243a75489d871858c4e1c940.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/293389873_jpg.rf.92a6975ed27c25750a0a21e1e2c22d70.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/4119_jpg.rf.837531a006c2dcf0019dd5d71ad980d8.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/4497_jpg.rf.7bd29b75a79b504c068bab5bf11f4c59.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/886_jpg.rf.5fe9dcd75ae76222541622b9190f19ef.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/-24-11-2021-235305_jpg.rf.5a282b392d0b24381e40a4f3cc433066.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/image18_jpeg.rf.98c74ec0df3c1a2ddc8865ecf314cece.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20211120_100124_jpg.rf.5484c994d5a6fc75a5634e0dc2d0a03f.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220405_211523_jpg.rf.53ee96fb780bbde8a11af4d9955bda14.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/23_jpg.rf.8a884028c4e37b6f125f1b5066514df7.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/garbage-26_jpg.rf.3ee49cea737d9b42a7d65fb4f6affb92.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/703_blur_gridmask_jpg.rf.9ed504cab64a15c0bc748a3b8db4316e.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/4921_jpg.rf.40d7cd1a669c40935a05e1c7c074b07c.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1483_jpg.rf.797ce90b81af2e7ca5a6efd1f33a6771.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1030_jpg.rf.cf11d26339ae3a5e6e2a270a026d9eb0.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_173556_jpg.rf.ea3a2bb6fd02b35c3cbc04c7fe8df304.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/images49_jpg.rf.ed8f61527ef3322c67092d6aa4c18f35.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/-4_jpg.rf.c4a79bc31ac4281497044961dca9f528.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1996_jpg.rf.d265ab1a69a9d2b67cc72ca53a4c1d36.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/239_jpg.rf.e113ac2111b377097e6fc915267d4ecc.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_171521_jpg.rf.5b18f23d9bd4b50fd216032c585d40b0.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1984_jpg.rf.b192d48949b3a2e254c5396e0910f4ad.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/image11_jpeg.rf.5975ddfd77f92fe69ee66d3c82ff6aa0.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/-24-11-2021-235223_jpg.rf.1eb82d03c288dde0da65497ce4b26233.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/2177_jpg.rf.2fa9c57cd684c74c1ecb60f30c390af9.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/5844_jpg.rf.603fa3e9d19725684cb6ddca7ebfe3db.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/orange-car-hp-right-mercedez_png.rf.8f72394b1eb36d8e1289fec8d5663490.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/38_jpg.rf.0c4e0afef4afe9d15b484ab21a312516.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/914_blur_gridmask_jpg.rf.ef4b9fc92aa026a7abb8e2791cad6938.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/vse-o-ploshchadkah-dlya-musornyh-kontejnerov-7_jpg.rf.897e4706083e95dba574767bec3024f2.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/227_jpg.rf.dbd6a071cb963a6aa0ffcf5161861908.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/4245_jpg.rf.d10b276475c0d7449c14dfa452cc5ca4.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/images-19-_jpg.rf.5c8ab34e426d6ee237ea0a3e7e89b322.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/what-car-suits-you-best-quiz_jpg.rf.cb5984716ae45788634fcd2bf36d1758.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_170447_jpg.rf.f204026822fadea92be31ff7ec87108e.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/3613_jpg.rf.2957535f632014fead0f8c60d26a4563.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/gettyimages-969597416-612x612_jpg.rf.e28a3872758e642667f61d9c1d961c15.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/nissan-altima-new_png.rf.a53cd8de7d7eb92186918caa5ce6d49f.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/garbage-pile-isolated-garbage-pile-isolated-white-background-126778450_jpg.rf.32c00bb381d1e832e646f5675db18582.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/trash-can-filled-with-garbage-along-street-in-nature-M8T7KW_jpg.rf.7684aae13bcd591c3311294fdc816d2a.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_171203_jpg.rf.9baa406c351c0c99f71cfc1c44f4c325.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/images35_jpg.rf.0d9b38833d15a8d7d33cbeb39c59b598.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/861_jpg.rf.a2fa15cdebff005171fa09b04a7c5fa5.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/images41_jpg.rf.6d8f39ceff515e34bac9819ec587f670.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/729_jpg.rf.8f782ba46fd1d94b01177a358096e74d.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/zc_jpg.rf.b2a63b33f9107792111f5371553ab9b8.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/470_jpg.rf.62843ad3e523a35fe44596991c017937.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1908-Ford-Model-T_0_jpg.rf.cf0f71dbddc73a6a34ba45e6a854e57f.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/-24-11-2021-234651_jpg.rf.7b38854d724d38cf090c4afbb17ed539.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1836_jpg.rf.6c19a6085834b5086074376c96d17630.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/2320_jpg.rf.c334db3890d979debd2b6d3bbcbb908d.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/Afghan-children-walk-by-solid-waste_Resized_0_jpg.rf.5bfc2fc6b1f8eb901de8ce15ee1eb174.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/2835_jpg.rf.c78dbc941e1c2d7e24880d279155fd86.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_175110_jpg.rf.2233ff22e8c3b7df9530bbb10e036e0d.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/5139_jpg.rf.29e024afaaac2021cdaeda6d6ee6f385.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/4023_jpg.rf.5d1679b5f50653fb31ac53e65eea66c5.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1770_jpg.rf.7e3357b1f1cd6adf0aea32e06d00d1ab.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/lucid-roundup-TA_jpg.rf.da3f064a63a97c404d549a5114635f74.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/570_jpg.rf.637f0d1d38f84e4eddbcd023fd7ff24f.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1955_jpg.rf.83ea4b73ceb58cc3b412fcdeeebacdab.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/50_jpg.rf.c34f5a5b3961650e22dcd5fbce65e2e9.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_165409_jpg.rf.8fbfcef619a2c2541d1cbfc2e186cde8.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/67897757_728520064266636_963326469746982912_n-1_jpg.rf.2a38363e08c837a6f0721a6ad3a42ae9.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/3193-jpg_blur_jpg.rf.139b8475901a485e18d6ff960c35a9a3.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_174824_jpg.rf.f745cafdf7a6c53a16cacb0fe91268c8.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/-80_jpg.rf.77c7f814b5ca7e4c12ffb50e25f7aa3d.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/maxresdefault_jpg.rf.ef3fb4cb93f9d90a9f471d489f476fbb.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/garbage-24_jpg.rf.45f3055e77abd0742d83add117353163.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/ze_jpg.rf.56af1f4d7d82d5f3cae15e0e4a6d21dd.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/738_jpg.rf.46b2fafae47d4d4a5f88706b4e398f09.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/5_jpg.rf.442848df251c713ed2d6339d71071b54.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/4036-jpg_gridmask_jpg.rf.7c7345dd9c7e3f4db29fe6f7ec60b962.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20211120_092849_jpg.rf.cfee2872552c045290ef62d0ce85a288.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/root1628149491882780_jpg.rf.fc1aeb90577a258a11936f7e1ef83045.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20211120_095830_jpg.rf.61a72fdbe24bf330259d88a36ae6e8e2.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/4082_jpg.rf.afd7e7efe0c557a52c5d620e6ff547f3.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/4073_jpg.rf.214efec249708ae52f23ba72cf6ea23b.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/image-2-_jpg.rf.7fddc3e15e079eb2e8c87b1cd0638ec6.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/3139-jpg_blur-jpg_gridmask_jpg.rf.f3ac5afd4dcd4029e516ced07a681b5c.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/370_jpg.rf.1a151f43bd87d3dcee0f41b6b8e46567.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20220404_173907_jpg.rf.af74e06dc57cfda0331e000bd3ea6694.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/ty_jpg.rf.c65a903394d4de35c553bb3146a5d04a.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1632_jpg.rf.695b2f377243ae3fce8d20a463955942.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/image9_jpeg.rf.8b9b0812872cb9998ea209ebd1fe3afa.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/1503_jpg.rf.01fa468a92cac2b700b77708da02ad5d.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/images21_jpg.rf.df13bf6815f4f3366b71b4cc94ff2766.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/3249-jpg_gridmask_jpg.rf.2541fd174e37cac35c0b71fbdf0b24d9.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/310_jpg.rf.91cd8fbfe48f3e13ea4e9e306d0d93a2.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/images-24-_jpg.rf.f824a88f5b30b0d440626601be7823ca.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/-85_jpg.rf.30fe8f1b7b75be0f1a1223d87815948f.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/Damaged_trash_can_28prague29-JPG_jpg.rf.1e7f76f32ec83c45b50386e21925862c.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/77_jpg.rf.175f43652846287680a0a62942cd187e.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/IMG_20211120_095941_jpg.rf.154bc8179567b012b526721a3f1bb5d0.jpg
# /kaggle/input/datasets/prachiii33/garbagebin/train/images/2645-jpg_gridmask_jpg.rf.62fc702c1beaf2098ec7b05aa84355c5.jpg
# /kaggle/input/datasets/prachiii33/videos/istockphoto-1335925810-640_adpp_is.mp4
# /kaggle/input/datasets/prachiii33/videos/istockphoto-2203584274-640_adpp_is.mp4

# %%
# !pip install -q ultralytics gradio pandas pyyaml scikit-learn opencv-python-headless

# %%
import os
import shutil
import random
import subprocess
import uuid
import csv
import json

from pathlib import Path
from collections import Counter, defaultdict
from datetime import datetime

import cv2
import numpy as np
import pandas as pd
import yaml
import torch

from sklearn.model_selection import train_test_split
from ultralytics import YOLO

print("All libraries imported successfully.")
# Out:
# All libraries imported successfully.

# %%
EXPECTED_CLASSES = [
    "Broken trash can",
    "Healthy trash can",
    "Trash can closed",
    "Trash can open",
    "Trash over flow"
]


def find_dataset_root():

    search_roots = [
        Path("/kaggle/input"),
        Path("/kaggle/working")
    ]

    candidates = []

    for root in search_roots:

        if not root.exists():
            continue

        for yaml_file in root.rglob("data.yaml"):

            try:

                with open(
                    yaml_file,
                    "r",
                    encoding="utf-8"
                ) as f:
                    data = yaml.safe_load(f)

                names = data.get("names", [])

                if isinstance(names, dict):
                    names = list(names.values())

                names = [str(x) for x in names]

                if names == EXPECTED_CLASSES:

                    candidates.append(
                        yaml_file.parent
                    )

            except Exception:
                continue

    if not candidates:

        raise FileNotFoundError(
            "Could not automatically find your dataset.\n"
            "Please set DATASET_SOURCE manually."
        )

    # Prefer Kaggle input over working directory
    candidates.sort(
        key=lambda p:
        0 if str(p).startswith("/kaggle/input")
        else 1
    )

    return candidates[0]


DATASET_SOURCE = find_dataset_root()

print("Dataset found at:")
print(DATASET_SOURCE)
# Out:
# Dataset found at:
# /kaggle/input/datasets/prachiii33/garbagebin

# %%
DATA_YAML_SOURCE = DATASET_SOURCE / "data.yaml"

with open(
    DATA_YAML_SOURCE,
    "r",
    encoding="utf-8"
) as f:

    original_yaml = yaml.safe_load(f)

print("Classes found in dataset:")

names = original_yaml["names"]

if isinstance(names, dict):
    names = list(names.values())

for i, name in enumerate(names):
    print(f"{i}: {name}")
# Out:
# Classes found in dataset:
# 0: Broken trash can
# 1: Healthy trash can
# 2: Trash can closed
# 3: Trash can open
# 4: Trash over flow

# %%
PROJECT_DIR = Path(
    "/kaggle/working/trash_can_overflow_project"
)

SPLIT_DATASET = (
    PROJECT_DIR /
    "dataset"
)

TRAIN_IMG = (
    SPLIT_DATASET /
    "train" /
    "images"
)

TRAIN_LBL = (
    SPLIT_DATASET /
    "train" /
    "labels"
)

VAL_IMG = (
    SPLIT_DATASET /
    "valid" /
    "images"
)

VAL_LBL = (
    SPLIT_DATASET /
    "valid" /
    "labels"
)

TEST_IMG = (
    SPLIT_DATASET /
    "test" /
    "images"
)

TEST_LBL = (
    SPLIT_DATASET /
    "test" /
    "labels"
)


for folder in [
    TRAIN_IMG,
    TRAIN_LBL,
    VAL_IMG,
    VAL_LBL,
    TEST_IMG,
    TEST_LBL
]:

    folder.mkdir(
        parents=True,
        exist_ok=True
    )

print("Clean dataset structure created.")
# Out:
# Clean dataset structure created.

# %%
IMAGE_EXTENSIONS = {
    ".jpg",
    ".jpeg",
    ".png",
    ".bmp",
    ".webp"
}


def collect_pairs(dataset_root):

    pairs = []

    for image_file in dataset_root.rglob("*"):

        if (
            not image_file.is_file()
            or
            image_file.suffix.lower()
            not in IMAGE_EXTENSIONS
        ):
            continue

        label_file = (
            image_file.parent.parent /
            "labels" /
            f"{image_file.stem}.txt"
        )

        if not label_file.exists():

            # Search more broadly
            possible = list(
                dataset_root.rglob(
                    f"{image_file.stem}.txt"
                )
            )

            if possible:
                label_file = possible[0]

        if label_file.exists():

            pairs.append(
                (
                    image_file,
                    label_file
                )
            )

    return pairs


pairs = collect_pairs(
    DATASET_SOURCE
)

print(
    f"Image-label pairs found: {len(pairs)}"
)

if len(pairs) < 100:

    raise RuntimeError(
        "Too few image-label pairs were found. "
        "Check the dataset path and structure."
    )
# Out:
# Image-label pairs found: 1974

# %%
class_counter = Counter()

for _, label_file in pairs:

    with open(
        label_file,
        "r",
        encoding="utf-8"
    ) as f:

        for line in f:

            parts = line.strip().split()

            if not parts:
                continue

            class_id = int(parts[0])

            class_counter[class_id] += 1


print("Object counts:")

for class_id in range(5):

    print(
        f"{class_id} - "
        f"{EXPECTED_CLASSES[class_id]}: "
        f"{class_counter[class_id]}"
    )
# Out:
# Object counts:
# 0 - Broken trash can: 351
# 1 - Healthy trash can: 602
# 2 - Trash can closed: 560
# 3 - Trash can open: 532
# 4 - Trash over flow: 1593

# %%
def get_primary_class(label_file):

    counts = Counter()

    with open(
        label_file,
        "r",
        encoding="utf-8"
    ) as f:

        for line in f:

            parts = line.strip().split()

            if not parts:
                continue

            class_id = int(parts[0])

            counts[class_id] += 1

    if not counts:
        return -1

    return counts.most_common(1)[0][0]


primary_classes = [
    get_primary_class(label)
    for _, label in pairs
]

valid_pairs = []

valid_primary = []

for pair, cls in zip(
    pairs,
    primary_classes
):

    if cls >= 0:
        valid_pairs.append(pair)
        valid_primary.append(cls)


pairs = valid_pairs
primary_classes = valid_primary


try:

    train_pairs, temp_pairs = train_test_split(
        pairs,
        test_size=0.20,
        random_state=42,
        stratify=primary_classes
    )

    temp_classes = [
        get_primary_class(label)
        for _, label in temp_pairs
    ]

    val_pairs, test_pairs = train_test_split(
        temp_pairs,
        test_size=0.50,
        random_state=42,
        stratify=temp_classes
    )

except ValueError:

    print(
        "Stratified split unavailable. "
        "Using random split instead."
    )

    train_pairs, temp_pairs = train_test_split(
        pairs,
        test_size=0.20,
        random_state=42
    )

    val_pairs, test_pairs = train_test_split(
        temp_pairs,
        test_size=0.50,
        random_state=42
    )


print(
    "TRAIN:",
    len(train_pairs)
)

print(
    "VALID:",
    len(val_pairs)
)

print(
    "TEST:",
    len(test_pairs)
)
# Out:
# TRAIN: 1409
# VALID: 176
# TEST: 177

# %%
def copy_pairs(
    pairs,
    image_destination,
    label_destination,
    split_name
):

    for index, (
        image_file,
        label_file
    ) in enumerate(pairs):

        new_stem = (
            f"{split_name}_{index:05d}"
        )

        new_image = (
            image_destination /
            f"{new_stem}{image_file.suffix.lower()}"
        )

        new_label = (
            label_destination /
            f"{new_stem}.txt"
        )

        shutil.copy2(
            image_file,
            new_image
        )

        shutil.copy2(
            label_file,
            new_label
        )


copy_pairs(
    train_pairs,
    TRAIN_IMG,
    TRAIN_LBL,
    "train"
)

copy_pairs(
    val_pairs,
    VAL_IMG,
    VAL_LBL,
    "valid"
)

copy_pairs(
    test_pairs,
    TEST_IMG,
    TEST_LBL,
    "test"
)

print("Dataset split completed.")
# Out:
# Dataset split completed.

# %%
def count_files(
    folder,
    extensions
):

    return len([
        f
        for f in folder.iterdir()
        if f.is_file()
        and f.suffix.lower()
        in extensions
    ])


for split in [
    "train",
    "valid",
    "test"
]:

    img_dir = (
        SPLIT_DATASET /
        split /
        "images"
    )

    lbl_dir = (
        SPLIT_DATASET /
        split /
        "labels"
    )

    images = count_files(
        img_dir,
        IMAGE_EXTENSIONS
    )

    labels = count_files(
        lbl_dir,
        {".txt"}
    )

    print(
        f"\n{split.upper()}"
    )

    print(
        "Images :",
        images
    )

    print(
        "Labels :",
        labels
    )

    if images != labels:

        raise RuntimeError(
            f"{split}: image/label mismatch!"
        )
# Out:
# TRAIN
# Images : 1409
# Labels : 1409
#
# VALID
# Images : 176
# Labels : 176
#
# TEST
# Images : 177
# Labels : 177

# %%
NEW_DATA_YAML = (
    SPLIT_DATASET /
    "data.yaml"
)

dataset_config = {

    "path": str(SPLIT_DATASET),

    "train": "train/images",

    "val": "valid/images",

    "test": "test/images",

    "names": EXPECTED_CLASSES

}


with open(
    NEW_DATA_YAML,
    "w",
    encoding="utf-8"
) as f:

    yaml.safe_dump(
        dataset_config,
        f,
        sort_keys=False
    )


print(
    NEW_DATA_YAML.read_text()
)
# Out:
# path: /kaggle/working/trash_can_overflow_project/dataset
# train: train/images
# val: valid/images
# test: test/images
# names:
# - Broken trash can
# - Healthy trash can
# - Trash can closed
# - Trash can open
# - Trash over flow

# %%
def get_safe_device():

    if not torch.cuda.is_available():

        print(
            "CUDA unavailable → using CPU."
        )

        return "cpu"

    try:

        test_tensor = torch.zeros(
            1,
            device="cuda"
        )

        _ = test_tensor + 1

        torch.cuda.synchronize()

        print(
            "CUDA test successful."
        )

        print(
            "GPU:",
            torch.cuda.get_device_name(0)
        )

        return 0

    except Exception as e:

        print(
            "CUDA runtime test failed:"
        )

        print(e)

        print(
            "Falling back to CPU."
        )

        return "cpu"


DEVICE = get_safe_device()

print(
    "Selected device:",
    DEVICE
)
# Out:
# CUDA test successful.
# GPU: Tesla T4
# Selected device: 0

# %%
PRETRAINED_MODEL = "yolov8n.pt"

model = YOLO(
    PRETRAINED_MODEL
)

print(
    "Pretrained YOLOv8 model loaded."
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 24.1MB/s 0.3s.2s<0.2s4s
# Pretrained YOLOv8 model loaded.

# %%
TRAINING_DIR = (
    PROJECT_DIR /
    "training"
)


training_results = model.train(

    data=str(
        NEW_DATA_YAML
    ),

    epochs=30,

    imgsz=640,

    batch=8,

    workers=2,

    patience=8,

    project=str(
        TRAINING_DIR
    ),

    name="trash_can_yolov8",

    exist_ok=True,

    device=DEVICE,

    pretrained=True,

    verbose=True

)

print(
    "Training completed."
)
# Out:
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/trash_can_overflow_project/dataset/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=trash_can_yolov8, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=8, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/trash_can_overflow_project/training, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/trash_can_overflow_project/training/trash_can_yolov8, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 4.8MB/s 0.2s 0.1s<0.2s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752287  ultralytics.nn.modules.head.Detect           [5, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,823 parameters, 3,011,807 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 13.2MB/s 0.4s.3s<0.1s2s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1703.5±691.5 MB/s, size: 64.4 KB)
# train: Scanning /kaggle/working/trash_can_overflow_project/dataset/train/labels... 1409 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1409/1409 1.4Kit/s 1.0s0.0s
# train: New cache created: /kaggle/working/trash_can_overflow_project/dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 768.5±694.7 MB/s, size: 49.7 KB)
# val: Scanning /kaggle/working/trash_can_overflow_project/dataset/valid/labels... 176 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 176/176 1.2Kit/s 0.1s<0.1s
# val: New cache created: /kaggle/working/trash_can_overflow_project/dataset/valid/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to /kaggle/working/trash_can_overflow_project/training/trash_can_yolov8/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/trash_can_overflow_project/training/trash_can_yolov8
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      1.11G      1.247      2.842      1.554          3        640: 100% ━━━━━━━━━━━━ 177/177 10.1it/s 17.5s.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 5.6it/s 2.0s0.1s
#                    all        176        367      0.303      0.539      0.329      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30       1.3G      1.291       2.26       1.55          2        640: 100% ━━━━━━━━━━━━ 177/177 11.2it/s 15.8s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 9.9it/s 1.1s0.1s
#                    all        176        367      0.408       0.47      0.402      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30       1.3G      1.317      2.163      1.568          3        640: 100% ━━━━━━━━━━━━ 177/177 11.4it/s 15.5s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 10.4it/s 1.1s.1s
#                    all        176        367      0.419       0.48      0.426      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30       1.3G      1.301      2.069      1.563          3        640: 100% ━━━━━━━━━━━━ 177/177 11.3it/s 15.6s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 10.1it/s 1.1s.1s
#                    all        176        367      0.466      0.464      0.459      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30       1.3G      1.264      1.922       1.52          7        640: 100% ━━━━━━━━━━━━ 177/177 11.2it/s 15.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 10.5it/s 1.0s2s
#                    all        176        367      0.591      0.554      0.534      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30       1.3G      1.261      1.875      1.527          1        640: 100% ━━━━━━━━━━━━ 177/177 11.2it/s 15.8s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 10.3it/s 1.1s2s
#                    all        176        367      0.588      0.537      0.519      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30       1.3G      1.227      1.745        1.5          4        640: 100% ━━━━━━━━━━━━ 177/177 11.2it/s 15.8s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 10.8it/s 1.0s.1s
#                    all        176        367      0.622       0.56      0.565      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30       1.3G      1.189      1.681      1.475          9        640: 100% ━━━━━━━━━━━━ 177/177 11.2it/s 15.8s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.0it/s 1.0s.1s
#                    all        176        367      0.632      0.607      0.605      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30       1.3G       1.18      1.627      1.457          9        640: 100% ━━━━━━━━━━━━ 177/177 11.3it/s 15.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.1it/s 1.0s2s
#                    all        176        367      0.647      0.546      0.613       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/30       1.3G      1.168      1.602      1.453          1        640: 100% ━━━━━━━━━━━━ 177/177 11.3it/s 15.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.1it/s 1.0s2s
#                    all        176        367      0.558      0.569      0.542      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/30       1.3G      1.146      1.563      1.445          1        640: 100% ━━━━━━━━━━━━ 177/177 11.3it/s 15.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.2it/s 1.0s.1s
#                    all        176        367      0.663       0.61      0.645      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/30       1.3G      1.121      1.442      1.416          2        640: 100% ━━━━━━━━━━━━ 177/177 11.3it/s 15.7s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 10.7it/s 1.0s.1s
#                    all        176        367      0.711      0.573      0.624      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/30       1.3G      1.084      1.398      1.387          4        640: 100% ━━━━━━━━━━━━ 177/177 11.3it/s 15.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.3it/s 1.0s.1s
#                    all        176        367      0.692      0.633      0.689      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/30       1.3G      1.091      1.406      1.397          2        640: 100% ━━━━━━━━━━━━ 177/177 11.3it/s 15.7s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 10.7it/s 1.0s2s
#                    all        176        367      0.686      0.668      0.697      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/30       1.3G      1.088      1.388      1.393          2        640: 100% ━━━━━━━━━━━━ 177/177 11.3it/s 15.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.0it/s 1.0s.1s
#                    all        176        367      0.757      0.642      0.708      0.491
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/30       1.3G      1.054      1.327      1.367          7        640: 100% ━━━━━━━━━━━━ 177/177 11.2it/s 15.8s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.1it/s 1.0s2s
#                    all        176        367      0.726      0.706      0.728      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/30       1.3G      1.047      1.292      1.353          2        640: 100% ━━━━━━━━━━━━ 177/177 11.2it/s 15.8s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.1it/s 1.0s0.1s
#                    all        176        367      0.717      0.641      0.701        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/30       1.3G      1.038      1.262      1.345          1        640: 100% ━━━━━━━━━━━━ 177/177 11.3it/s 15.7s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 10.9it/s 1.0s.1s
#                    all        176        367      0.749      0.653      0.727      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/30       1.3G       1.02      1.225      1.337          6        640: 100% ━━━━━━━━━━━━ 177/177 11.2it/s 15.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.1it/s 1.0s.1s
#                    all        176        367      0.697      0.627      0.704      0.513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/30       1.3G     0.9985      1.206      1.319          4        640: 100% ━━━━━━━━━━━━ 177/177 11.2it/s 15.8s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.0it/s 1.0s.1s
#                    all        176        367      0.716      0.681      0.733      0.533
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/30       1.3G     0.9566      1.108      1.324          2        640: 100% ━━━━━━━━━━━━ 177/177 11.1it/s 15.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.4it/s 1.0s.1s
#                    all        176        367      0.745      0.667      0.726      0.533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30       1.3G     0.9152      1.036      1.299          2        640: 100% ━━━━━━━━━━━━ 177/177 11.6it/s 15.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.2it/s 1.0s2s
#                    all        176        367      0.801      0.597      0.708      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30       1.3G     0.9095     0.9686      1.289          1        640: 100% ━━━━━━━━━━━━ 177/177 11.5it/s 15.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 10.8it/s 1.0s2s
#                    all        176        367      0.829      0.618      0.732      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30       1.3G     0.8746     0.9589      1.275          9        640: 100% ━━━━━━━━━━━━ 177/177 11.6it/s 15.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.3it/s 1.0s.1s
#                    all        176        367      0.785      0.669      0.753       0.54
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30       1.3G     0.8617      0.929       1.26          2        640: 100% ━━━━━━━━━━━━ 177/177 11.5it/s 15.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.3it/s 1.0s.1s
#                    all        176        367      0.756      0.695      0.753      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30       1.3G     0.8451     0.8821      1.252          1        640: 100% ━━━━━━━━━━━━ 177/177 11.7it/s 15.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.3it/s 1.0s.1s
#                    all        176        367      0.789      0.698      0.756      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30       1.3G     0.8343     0.8594      1.243          1        640: 100% ━━━━━━━━━━━━ 177/177 11.6it/s 15.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 10.9it/s 1.0s.1s
#                    all        176        367      0.787      0.677      0.764      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30       1.3G     0.8197     0.8134      1.225          1        640: 100% ━━━━━━━━━━━━ 177/177 11.6it/s 15.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.4it/s 1.0s.1s
#                    all        176        367      0.819        0.7      0.783       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30       1.3G     0.8069     0.7982      1.219          2        640: 100% ━━━━━━━━━━━━ 177/177 11.6it/s 15.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.1it/s 1.0s.1s
#                    all        176        367      0.824      0.673       0.77      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30       1.3G     0.7842      0.767      1.201          2        640: 100% ━━━━━━━━━━━━ 177/177 11.6it/s 15.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 11.5it/s 1.0s2s
#                    all        176        367      0.809      0.695      0.772      0.569
#
# 30 epochs completed in 0.142 hours.
# Optimizer stripped from /kaggle/working/trash_can_overflow_project/training/trash_can_yolov8/weights/last.pt, 6.2MB
# Optimizer stripped from /kaggle/working/trash_can_overflow_project/training/trash_can_yolov8/weights/best.pt, 6.2MB
#
# Validating /kaggle/working/trash_can_overflow_project/training/trash_can_yolov8/weights/best.pt...
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# Model summary (fused): 73 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 11/11 5.7it/s 1.9s0.1s
#                    all        176        367       0.82      0.699      0.783      0.569
#       Broken trash can         28         37      0.877      0.622      0.748      0.563
#      Healthy trash can         43         64      0.654      0.532      0.627      0.408
#       Trash can closed         30         59      0.882      0.757      0.807      0.621
#         Trash can open         39         56       0.89      0.929      0.969      0.762
#        Trash over flow         84        151      0.799      0.656      0.763      0.488
# Speed: 0.4ms preprocess, 4.7ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to /kaggle/working/trash_can_overflow_project/training/trash_can_yolov8
# Training completed.

# %%
BEST_MODEL = (
    TRAINING_DIR /
    "trash_can_yolov8" /
    "weights" /
    "best.pt"
)

if not BEST_MODEL.exists():

    raise FileNotFoundError(
        f"best.pt was not found at:\n"
        f"{BEST_MODEL}"
    )

print(
    "Best model found:"
)

print(
    BEST_MODEL
)
# Out:
# Best model found:
# /kaggle/working/trash_can_overflow_project/training/trash_can_yolov8/weights/best.pt

# %%
trained_model = YOLO(
    str(BEST_MODEL)
)

print(
    "Fine-tuned trash-can model loaded."
)

print(
    "Classes:"
)

for index, name in trained_model.names.items():

    print(
        index,
        "→",
        name
    )
# Out:
# Fine-tuned trash-can model loaded.
# Classes:
# 0 → Broken trash can
# 1 → Healthy trash can
# 2 → Trash can closed
# 3 → Trash can open
# 4 → Trash over flow

# %%
validation_results = trained_model.val(
    data=str(NEW_DATA_YAML),
    split="val",
    imgsz=640,
    batch=8,
    device=DEVICE
)

print(
    "Validation completed."
)
# Out:
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# Model summary (fused): 73 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2055.4±372.8 MB/s, size: 68.7 KB)
# val: Scanning /kaggle/working/trash_can_overflow_project/dataset/valid/labels.cache... 176 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 176/176 82.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 10.8it/s 2.0s0.1s
#                    all        176        367      0.823      0.698      0.783      0.569
#       Broken trash can         28         37      0.879      0.622      0.749      0.562
#      Healthy trash can         43         64      0.665      0.531      0.625      0.407
#       Trash can closed         30         59      0.881      0.753      0.807      0.625
#         Trash can open         39         56      0.891      0.929      0.969      0.764
#        Trash over flow         84        151      0.799      0.656      0.763      0.487
# Speed: 1.7ms preprocess, 4.4ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
# Validation completed.

# %%
validation_results = trained_model.val(
    data=str(NEW_DATA_YAML),
    split="val",
    imgsz=640,
    batch=8,
    device=DEVICE
)

print(
    "Validation completed."
)
# Out:
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1838.6±813.5 MB/s, size: 72.1 KB)
# val: Scanning /kaggle/working/trash_can_overflow_project/dataset/valid/labels.cache... 176 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 176/176 82.0Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 10.4it/s 2.1s0.1s
#                    all        176        367      0.823      0.698      0.783      0.569
#       Broken trash can         28         37      0.879      0.622      0.749      0.562
#      Healthy trash can         43         64      0.665      0.531      0.625      0.407
#       Trash can closed         30         59      0.881      0.753      0.807      0.625
#         Trash can open         39         56      0.891      0.929      0.969      0.764
#        Trash over flow         84        151      0.799      0.656      0.763      0.487
# Speed: 1.9ms preprocess, 4.4ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val-2
# Validation completed.

# %%
test_results = trained_model.val(
    data=str(NEW_DATA_YAML),
    split="test",
    imgsz=640,
    batch=8,
    device=DEVICE
)

print(
    "Test evaluation completed."
)
# Out:
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1436.2±585.4 MB/s, size: 56.7 KB)
# val: Scanning /kaggle/working/trash_can_overflow_project/dataset/test/labels... 177 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 177/177 1.3Kit/s 0.1s<0.1s
# val: New cache created: /kaggle/working/trash_can_overflow_project/dataset/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 23/23 10.6it/s 2.2s0.1s
#                    all        177        341      0.856      0.669      0.816      0.608
#       Broken trash can         28         28      0.828      0.643      0.776      0.585
#      Healthy trash can         45         60      0.755       0.55      0.738      0.551
#       Trash can closed         37         60      0.918      0.767      0.881       0.71
#         Trash can open         31         39      0.921      0.795        0.9      0.684
#        Trash over flow         87        154      0.859      0.592      0.783      0.511
# Speed: 1.3ms preprocess, 4.6ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val-3
# Test evaluation completed.

# %%
sample_images = list(
    TEST_IMG.glob("*")
)

if not sample_images:

    raise RuntimeError(
        "No test images found."
    )

sample_image = sample_images[0]

prediction = trained_model.predict(
    source=str(sample_image),
    conf=0.35,
    save=True,
    project=str(
        PROJECT_DIR /
        "prediction"
    ),
    name="sample",
    exist_ok=True,
    device=DEVICE
)

print(
    "Prediction completed."
)

print(
    "Image:",
    sample_image
)
# Out:
# image 1/1 /kaggle/working/trash_can_overflow_project/dataset/test/images/test_00049.jpg: 640x640 1 Broken trash can, 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /kaggle/working/trash_can_overflow_project/prediction/sample
# Prediction completed.
# Image: /kaggle/working/trash_can_overflow_project/dataset/test/images/test_00049.jpg

# %%
from IPython.display import display, Image

prediction_dir = (
    PROJECT_DIR /
    "prediction" /
    "sample"
)

predicted_images = list(
    prediction_dir.glob("*")
)

if predicted_images:

    display(
        Image(
            filename=str(
                predicted_images[0]
            )
        )
    )

# %%
# ============================================================
# PROFESSIONAL ALERT BAR
# ============================================================

import cv2
from datetime import datetime

CLASS_COLORS = {

    0:(255,0,255),      # Broken
    1:(0,255,0),        # Healthy
    2:(0,255,0),        # Closed
    3:(0,255,255),      # Open
    4:(0,0,255)         # Overflow

}


def draw_alert_banner(
        frame,
        detected_classes,
        overflow_tracks,
        fps,
        frame_number
):

    h, w = frame.shape[:2]

    banner_height = 75

    # ---------------------------------------
    # Decide banner colour
    # ---------------------------------------

    if 4 in detected_classes:

        banner_color = (0,0,255)

        title = "CRITICAL ALERT"

        message = "TRASH OVERFLOW DETECTED • IMMEDIATE CLEANING REQUIRED"

    elif 0 in detected_classes or 3 in detected_classes:

        banner_color = (0,215,255)

        title = "WARNING"

        message = "DAMAGED / OPEN TRASH BIN DETECTED"

    else:

        banner_color = (0,170,0)

        title = "NORMAL"

        message = "ALL TRASH BINS ARE OPERATING NORMALLY"

    # ---------------------------------------
    # Banner
    # ---------------------------------------

    overlay = frame.copy()

    cv2.rectangle(

        overlay,

        (0,h-banner_height),

        (w,h),

        banner_color,

        -1

    )

    frame = cv2.addWeighted(
        overlay,
        0.92,
        frame,
        0.08,
        0
    )

    # ---------------------------------------
    # Left text
    # ---------------------------------------

    cv2.putText(

        frame,

        title,

        (25,h-38),

        cv2.FONT_HERSHEY_DUPLEX,

        0.95,

        (255,255,255),

        2,

        cv2.LINE_AA

    )

    cv2.putText(

        frame,

        message,

        (25,h-12),

        cv2.FONT_HERSHEY_SIMPLEX,

        0.60,

        (255,255,255),

        2,

        cv2.LINE_AA

    )

    # ---------------------------------------
    # Right Information
    # ---------------------------------------

    current_time = frame_number/fps

    info = f"Overflow:{len(overflow_tracks)}   Time:{current_time:0.1f}s"

    size = cv2.getTextSize(

        info,

        cv2.FONT_HERSHEY_SIMPLEX,

        0.55,

        2

    )[0]

    cv2.putText(

        frame,

        info,

        (w-size[0]-20,h-25),

        cv2.FONT_HERSHEY_SIMPLEX,

        0.55,

        (255,255,255),

        2,

        cv2.LINE_AA

    )

    return frame

# %%
# ============================================================
# PROFESSIONAL SURVEILLANCE ALERT BAR
# ============================================================

import cv2
import numpy as np
from datetime import datetime

def draw_alert_banner(
    frame,
    detected_classes,
    overflow_tracks,
    fps,
    frame_number
):

    h, w = frame.shape[:2]

    banner_height = 90

    # -------------------------------------
    # Determine system state
    # -------------------------------------

    if 4 in detected_classes:

        banner = (0,0,255)

        state = "CRITICAL ALERT"

        message = "TRASH OVERFLOW DETECTED"

        action = "ACTION : DISPATCH CLEANING TEAM"

    elif 0 in detected_classes or 3 in detected_classes:

        banner = (0,215,255)

        state = "WARNING"

        message = "DAMAGED / OPEN TRASH BIN"

        action = "ACTION : INSPECTION REQUIRED"

    else:

        banner = (0,170,0)

        state = "NORMAL"

        message = "ALL TRASH BINS OPERATING NORMALLY"

        action = "SYSTEM MONITORING"

    # -------------------------------------
    # Dark transparent background
    # -------------------------------------

    overlay = frame.copy()

    cv2.rectangle(
        overlay,
        (0,h-banner_height),
        (w,h),
        (20,20,20),
        -1
    )

    frame = cv2.addWeighted(
        overlay,
        0.65,
        frame,
        0.35,
        0
    )

    # -------------------------------------
    # Left coloured strip
    # -------------------------------------

    cv2.rectangle(
        frame,
        (0,h-banner_height),
        (18,h),
        banner,
        -1
    )

    # -------------------------------------
    # Banner title
    # -------------------------------------

    cv2.putText(

        frame,

        state,

        (35,h-55),

        cv2.FONT_HERSHEY_DUPLEX,

        0.95,

        banner,

        2,

        cv2.LINE_AA

    )

    # -------------------------------------
    # Main message
    # -------------------------------------

    cv2.putText(

        frame,

        message,

        (35,h-28),

        cv2.FONT_HERSHEY_SIMPLEX,

        0.62,

        (255,255,255),

        2,

        cv2.LINE_AA

    )

    # -------------------------------------
    # Action line
    # -------------------------------------

    cv2.putText(

        frame,

        action,

        (35,h-8),

        cv2.FONT_HERSHEY_SIMPLEX,

        0.50,

        (230,230,230),

        1,

        cv2.LINE_AA

    )

    # -------------------------------------
    # Right side details
    # -------------------------------------

    current_time = frame_number/fps

    now = datetime.now().strftime("%H:%M:%S")

    info = [

        f"Camera : CAM-01",

        f"Overflow : {len(overflow_tracks)}",

        f"Video : {current_time:.1f}s",

        now

    ]

    y = h-58

    for item in info:

        size = cv2.getTextSize(
            item,
            cv2.FONT_HERSHEY_SIMPLEX,
            0.50,
            1
        )[0]

        cv2.putText(

            frame,

            item,

            (w-size[0]-20,y),

            cv2.FONT_HERSHEY_SIMPLEX,

            0.50,

            (255,255,255),

            1,

            cv2.LINE_AA

        )

        y += 18

    return frame

# %%
FINAL_OUTPUT = (
    PROJECT_DIR /
    "final_outputs"
)

FINAL_VIDEO_DIR = (
    FINAL_OUTPUT /
    "videos"
)

FINAL_SNAPSHOT_DIR = (
    FINAL_OUTPUT /
    "snapshots"
)

FINAL_REPORT_DIR = (
    FINAL_OUTPUT /
    "reports"
)

for folder in [
    FINAL_VIDEO_DIR,
    FINAL_SNAPSHOT_DIR,
    FINAL_REPORT_DIR
]:

    folder.mkdir(
        parents=True,
        exist_ok=True
    )

print(
    "Output directories ready."
)
# Out:
# Output directories ready.

# %%
def process_video(
    video_path,
    confidence=0.40,
    required_overflow_frames=10
):

    video_path = Path(video_path)

    if not video_path.exists():
        raise FileNotFoundError("Uploaded video not found.")

    # ----------------------------------------------------
    # Create unique output folder
    # ----------------------------------------------------

    run_id = uuid.uuid4().hex[:8]

    run_dir = FINAL_OUTPUT / f"run_{run_id}"
    run_dir.mkdir(parents=True, exist_ok=True)

    temp_video = run_dir / "annotated_temp.avi"
    final_video = run_dir / "annotated_output.mp4"

    snapshot_dir = run_dir / "snapshots"
    snapshot_dir.mkdir(parents=True, exist_ok=True)

    csv_path = run_dir / "overflow_events.csv"

    # ----------------------------------------------------
    # Open Video
    # ----------------------------------------------------

    cap = cv2.VideoCapture(str(video_path))

    if not cap.isOpened():
        raise ValueError("OpenCV could not open this video.")

    fps = cap.get(cv2.CAP_PROP_FPS)

    if fps <= 0:
        fps = 25.0

    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    if width <= 0 or height <= 0:
        cap.release()
        raise ValueError("Invalid video dimensions.")

    # ----------------------------------------------------
    # Output Video Writer
    # ----------------------------------------------------

    fourcc = cv2.VideoWriter_fourcc(*"MJPG")

    writer = cv2.VideoWriter(
        str(temp_video),
        fourcc,
        fps,
        (width, height)
    )

    if not writer.isOpened():
        cap.release()
        raise RuntimeError("Could not create output video.")

    # ----------------------------------------------------
    # Tracking Variables
    # ----------------------------------------------------

    overflow_frames = defaultdict(int)

    alerted_tracks = set()

    inactive_tracks = defaultdict(int)

    event_records = []

    frame_number = 0

    event_id = 0

    # ----------------------------------------------------
    # Main Loop
    # ----------------------------------------------------

    while True:

        success, frame = cap.read()

        if not success:
            break

        frame_number += 1

        # Used for blinking REC and overflow box
        blink = ((frame_number // 15) % 2 == 0)

        # Every frame starts fresh
        detected_classes = set()

        current_overflow_tracks = set()

        # ------------------------------------------------
        # YOLOv8 + ByteTrack
        # ------------------------------------------------

        results = trained_model.track(

            frame,

            persist=True,

            tracker="bytetrack.yaml",

            conf=confidence,

            device=DEVICE,

            verbose=False

        )

        result = results[0]

        annotated = frame.copy()

        # ------------------------------------------------
        # Process detections
        # ------------------------------------------------

        if result.boxes is not None:

            boxes = result.boxes

            for i in range(len(boxes)):

                class_id = int(boxes.cls[i].item())

                detected_classes.add(class_id)

                class_name = trained_model.names[class_id]

                score = float(boxes.conf[i].item())

                if score < confidence:
                    continue

                x1, y1, x2, y2 = map(
                    int,
                    boxes.xyxy[i].cpu().numpy()
                )

                track_id = None

                if boxes.id is not None:
                    track_id = int(boxes.id[i].item())

                # ------------------------------------------
                # Overflow Logic
                # ------------------------------------------

                is_overflow = (class_id == 4)

                if is_overflow and track_id is not None:

                    current_overflow_tracks.add(track_id)

                    overflow_frames[track_id] += 1

                elif track_id is not None:

                    overflow_frames[track_id] = max(
                        0,
                        overflow_frames[track_id] - 1
                    )

                # ------------------------------------------
                # Bounding box colour selection
                # ------------------------------------------

                if is_overflow:

                    if blink:
                        box_color = (0, 0, 255)
                    else:
                        box_color = (40, 40, 255)

                    label = (
                        f"OVERFLOW | "
                        f"ID:{track_id} | "
                        f"{score:.2f}"
                    )

                elif class_id == 3:

                    box_color = (0, 215, 255)

                    label = (
                        f"OPEN BIN | "
                        f"ID:{track_id} | "
                        f"{score:.2f}"
                    )

                elif class_id == 0:

                    box_color = (255, 0, 255)

                    label = (
                        f"BROKEN BIN | "
                        f"ID:{track_id} | "
                        f"{score:.2f}"
                    )

                else:

                    box_color = (0, 255, 0)

                    label = (
                        f"{class_name} | "
                        f"ID:{track_id} | "
                        f"{score:.2f}"
                    )

                cv2.rectangle(
                    annotated,
                    (x1, y1),
                    (x2, y2),
                    box_color,
                    3
                )

                cv2.putText(
                    annotated,
                    label,
                    (
                        x1,
                        max(25, y1 - 8)
                    ),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.55,
                    box_color,
                    2,
                    cv2.LINE_AA
                )

                # ==========================================================
                # CONFIRMED OVERFLOW EVENT
                # ==========================================================

                if (
                    is_overflow
                    and track_id is not None
                    and overflow_frames[track_id] >= required_overflow_frames
                    and track_id not in alerted_tracks
                ):

                    event_id += 1

                    timestamp = datetime.now().strftime(
                        "%Y-%m-%d %H:%M:%S"
                    )

                    video_seconds = frame_number / fps

                    snapshot_path = (
                        snapshot_dir /
                        f"event_{event_id}_frame_{frame_number}.jpg"
                    )

                    cv2.imwrite(
                        str(snapshot_path),
                        annotated
                    )

                    event_records.append({

                        "event_id": event_id,

                        "timestamp": timestamp,

                        "frame_number": frame_number,

                        "video_time_seconds": round(
                            video_seconds,
                            2
                        ),

                        "track_id": track_id,

                        "class": class_name,

                        "confidence": round(
                            score,
                            4
                        ),

                        "event": "TRASH OVERFLOW",

                        "snapshot": str(snapshot_path)

                    })

                    alerted_tracks.add(track_id)

        # ==========================================================
        # TOP HEADER
        # ==========================================================

        status_height = 75

        cv2.rectangle(
            annotated,
            (0, 0),
            (width, status_height),
            (25, 25, 25),
            -1
        )

        # ----------------------------------------------------------
        # Blinking REC Indicator
        # ----------------------------------------------------------

        if blink:

            cv2.circle(
                annotated,
                (width - 45, 28),
                8,
                (0, 0, 255),
                -1
            )

        cv2.putText(
            annotated,
            "REC",
            (width - 82, 34),
            cv2.FONT_HERSHEY_DUPLEX,
            0.60,
            (255, 255, 255),
            2
        )

        # ----------------------------------------------------------
        # Camera Name
        # ----------------------------------------------------------

        cv2.putText(
            annotated,
            "SMART TRASH CAN MONITOR",
            (20, 32),
            cv2.FONT_HERSHEY_DUPLEX,
            0.72,
            (255, 255, 255),
            2,
            cv2.LINE_AA
        )

        # ----------------------------------------------------------
        # Status Text
        # ----------------------------------------------------------

        if len(current_overflow_tracks) > 0:

            status_text = "STATUS : OVERFLOW DETECTED"

            status_color = (0, 0, 255)

        else:

            status_text = "STATUS : MONITORING"

            status_color = (0, 220, 0)

        cv2.putText(
            annotated,
            status_text,
            (20, 63),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.60,
            status_color,
            2,
            cv2.LINE_AA
        )

        # ----------------------------------------------------------
        # Event Counter
        # ----------------------------------------------------------

        cv2.putText(
            annotated,
            f"Events : {event_id}",
            (width - 180, 62),
            cv2.FONT_HERSHEY_SIMPLEX,
            0.60,
            (255, 255, 255),
            2,
            cv2.LINE_AA
        )

        # ==========================================================
        # PROFESSIONAL ALERT BANNER
        # ==========================================================

        annotated = draw_alert_banner(

            frame=annotated,

            detected_classes=detected_classes,

            overflow_tracks=current_overflow_tracks,

            fps=fps,

            frame_number=frame_number

        )

        # ==========================================================
        # WRITE FRAME
        # ==========================================================

        writer.write(annotated)

        # ==========================================================
        # PROGRESS
        # ==========================================================

        if frame_number % 100 == 0:

            if total_frames > 0:

                progress = (
                    frame_number /
                    total_frames
                ) * 100

                print(
                    f"Processing : {progress:.1f}%"
                )

    # ==========================================================
    # RELEASE RESOURCES
    # ==========================================================

    cap.release()
    writer.release()

    # ==========================================================
    # SAVE CSV REPORT
    # ==========================================================

    report_df = pd.DataFrame(event_records)

    if report_df.empty:

        report_df = pd.DataFrame(
            columns=[
                "event_id",
                "timestamp",
                "frame_number",
                "video_time_seconds",
                "track_id",
                "class",
                "confidence",
                "event",
                "snapshot"
            ]
        )

    report_df.to_csv(
        csv_path,
        index=False
    )

    # ==========================================================
    # CONVERT AVI → MP4
    # ==========================================================

    ffmpeg_available = shutil.which("ffmpeg") is not None

    if ffmpeg_available:

        command = [

            "ffmpeg",
            "-y",

            "-i",
            str(temp_video),

            "-c:v",
            "libx264",

            "-pix_fmt",
            "yuv420p",

            "-movflags",
            "+faststart",

            str(final_video)

        ]

        conversion = subprocess.run(

            command,

            stdout=subprocess.PIPE,

            stderr=subprocess.PIPE,

            text=True

        )

        if conversion.returncode != 0:

            print("⚠ FFmpeg conversion failed.")
            print(conversion.stderr)

            shutil.copy2(
                temp_video,
                final_video
            )

    else:

        print("⚠ FFmpeg not found. Copying AVI.")

        shutil.copy2(
            temp_video,
            final_video
        )

    # ==========================================================
    # SUMMARY
    # ==========================================================

    summary = {

        "total_frames":
        frame_number,

        "fps":
        round(
            fps,
            2
        ),

        "duration_seconds":
        round(
            frame_number / fps,
            2
        ),

        "overflow_events":
        event_id,

        "output_video":
        str(final_video),

        "csv_report":
        str(csv_path),

        "snapshot_directory":
        str(snapshot_dir)

    }

    print("\n========================================")

    print("Processing Complete")

    print(f"Frames Processed : {frame_number}")

    print(f"Overflow Events  : {event_id}")

    print(f"Output Video     : {final_video}")

    print(f"CSV Report       : {csv_path}")

    print("========================================\n")

    return (

        str(final_video),

        report_df,

        summary

    )

# %%
TEST_VIDEO = "/kaggle/input/datasets/prachiii33/videos/istockphoto-1335925810-640_adpp_is.mp4"

# %%
output_video, event_df, summary = process_video(
    video_path=TEST_VIDEO,
    confidence=0.40,
    required_overflow_frames=10
)

print(
    json.dumps(
        summary,
        indent=4
    )
)

display(event_df)
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 2 packages in 667ms
# Prepared 1 package in 306ms
# Installed 1 package in 5ms
#  + lap==0.5.13
#
# requirements: AutoUpdate success ✅ 1.3s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# Processing : 35.2%
# Processing : 70.4%
#
# ========================================
# Processing Complete
# Frames Processed : 284
# Overflow Events  : 3
# Output Video     : /kaggle/working/trash_can_overflow_project/final_outputs/run_99ef607f/annotated_output.mp4
# CSV Report       : /kaggle/working/trash_can_overflow_project/final_outputs/run_99ef607f/overflow_events.csv
# ========================================
#
# {
#     "total_frames": 284,
#     "fps": 25.0,
#     "duration_seconds": 11.36,
#     "overflow_events": 3,
#     "output_video": "/kaggle/working/trash_can_overflow_project/final_outputs/run_99ef607f/annotated_output.mp4",
#     "csv_report": "/kaggle/working/trash_can_overflow_project/final_outputs/run_99ef607f/overflow_events.csv",
#     "snapshot_directory": "/kaggle/working/trash_can_overflow_project/final_outputs/run_99ef607f/snapshots"
# }
#    event_id            timestamp  frame_number  video_time_seconds  track_id  \
# 0         1  2026-08-07 10:01:56            10                0.40         1
# 1         2  2026-08-07 10:01:57            43                1.72         2
# 2         3  2026-08-07 10:01:59           168                6.72         4
#
#              class  confidence           event  \
# 0  Trash over flow      0.7531  TRASH OVERFLOW
# 1  Trash over flow      0.4075  TRASH OVERFLOW
# 2  Trash over flow      0.4686  TRASH OVERFLOW
#
#                                             snapshot
# 0  /kaggle/working/trash_can_overflow_project/fin...
# 1  /kaggle/working/trash_can_overflow_project/fin...
# 2  /kaggle/working/trash_can_overflow_project/fin...

# %%
from IPython.display import Video, display

display(
    Video(
        output_video,
        embed=True
    )
)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
import gradio as gr

# %%
from pathlib import Path
import gradio as gr

def run_application(uploaded_video):

    if uploaded_video is None:
        raise gr.Error("Please upload a CCTV or surveillance video.")

    try:

        video_path, event_df, summary = process_video(
            video_path=uploaded_video,
            confidence=0.40,
            required_overflow_frames=10
        )

        snapshot_paths = []

        if event_df is not None and "snapshot" in event_df.columns:
            for snapshot in event_df["snapshot"].tolist():

                if Path(snapshot).exists():
                    snapshot_paths.append(
                        (snapshot, "Overflow Event")
                    )

        if summary["overflow_events"] > 0:

            status = (
                "🚨 OVERFLOW DETECTED\n\n"
                f"Confirmed events: {summary['overflow_events']}\n"
                f"Video duration: {summary['duration_seconds']} seconds"
            )

        else:

            status = (
                "✅ NO OVERFLOW EVENTS CONFIRMED\n\n"
                f"Video duration: {summary['duration_seconds']} seconds"
            )

        return (
            video_path,
            event_df,
            snapshot_paths,
            summary["csv_report"],
            status
        )

    except Exception as e:
        raise gr.Error(f"Processing failed:\n{str(e)}")

# %%
import gradio as gr

with gr.Blocks() as demo:

    gr.Markdown(
        """
        # 🗑️ Smart Trash Can Monitoring System

        ### AI-Based Trash Overflow Detection

        Upload a CCTV or surveillance video.
        The system detects trash cans, identifies
        overflowing bins, tracks them across frames,
        and generates evidence-backed overflow events.
        """
    )

    gr.Markdown(
        """
        **Detection Classes**

        🟢 Healthy trash can  
        🟢 Trash can closed  
        🟠 Trash can open  
        🟣 Broken trash can  
        🔴 Trash over flow
        """
    )

    # --------------------------------------------------
    # VIDEO INPUT
    # --------------------------------------------------

    video_input = gr.Video(
        label="Upload CCTV / Surveillance Video",
        sources=["upload"]
    )

    # --------------------------------------------------
    # PROCESS BUTTON
    # --------------------------------------------------

    process_button = gr.Button(
        "🚨 ANALYZE VIDEO",
        variant="primary"
    )

    # --------------------------------------------------
    # STATUS
    # --------------------------------------------------

    status_output = gr.Textbox(
        label="Expected Output / System Status",
        lines=4
    )

    # --------------------------------------------------
    # OUTPUTS
    # --------------------------------------------------

    with gr.Row():

        output_video = gr.Video(
            label="Annotated Output Video"
        )

        event_report = gr.File(
            label="Download Event Report"
        )

    event_table = gr.Dataframe(
        label="Confirmed Overflow Events",
        interactive=False
    )

    evidence_gallery = gr.Gallery(
        label="Overflow Evidence",
        columns=3,
        rows=2
    )

    # --------------------------------------------------
    # BUTTON ACTION
    # --------------------------------------------------

    process_button.click(
        fn=run_application,
        inputs=video_input,
        outputs=[
            output_video,
            event_table,
            evidence_gallery,
            event_report,
            status_output
        ]
    )


# ------------------------------------------------------
# LAUNCH
# ------------------------------------------------------

demo.launch(
    share=True,
    debug=True
)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://9cef99a81a7a54984b.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9cef99a81a7a54984b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Processing : 15.8%
# Processing : 31.6%
# Processing : 47.5%
# Processing : 63.3%
# Processing : 79.1%
# Processing : 94.9%
#
# ========================================
# Processing Complete
# Frames Processed : 632
# Overflow Events  : 5
# Output Video     : /kaggle/working/trash_can_overflow_project/final_outputs/run_ce6096a8/annotated_output.mp4
# CSV Report       : /kaggle/working/trash_can_overflow_project/final_outputs/run_ce6096a8/overflow_events.csv
# ========================================
